# %%
import pandas as pd
import os

# %%
source_csv = "hotels-properties-citywide-1.csv"

# %%
hotels_df = pd.read_csv(source_csv)

# %%
hotels_df.head()
# Out:
#         PARID  BOROCODE  BLOCK   LOT  TAXYEAR STREET NUMBER       STREET NAME  \
# 0  1000080039         1      8    39     2021            32      PEARL STREET
# 1  1000080051         1      8    51     2021             6      WATER STREET
# 2  1000100033         1     10    33     2021             8      STONE STREET
# 3  1000110029         1     11    29     2021            11      STONE STREET
# 4  1000161301         1     16  1301     2021           102  NORTH END AVENUE
#
#    Postcode BLDG_CLASS  TAXCLASS                   OWNER_NAME    Borough  \
# 0     10004         H3         4                32 PEARL, LLC  MANHATTAN
# 1     10004         H2         4                    AI IV LLC  MANHATTAN
# 2     10004         H2         4  B.H. 8 STONE STREET AG, LLC  MANHATTAN
# 3     10004         H2         4         PREMIER EMERALD, LLC  MANHATTAN
# 4     10282         RH         4                GOLDMAN SACHS  MANHATTAN
#
# ...

# %%
hotels_df['Street_Address'] = hotels_df['STREET NUMBER'].str.cat(hotels_df['STREET NAME'],sep=" ")
hotels_df
# Out:
#            PARID  BOROCODE  BLOCK   LOT  TAXYEAR STREET NUMBER  \
# 0     1000080039         1      8    39     2021            32
# 1     1000080051         1      8    51     2021             6
# 2     1000100033         1     10    33     2021             8
# 3     1000110029         1     11    29     2021            11
# 4     1000161301         1     16  1301     2021           102
# ...          ...       ...    ...   ...      ...           ...
# 2726  5038750026         5   3875    26     2021           630
# 2727  5066680094         5   6668    94     2021            51
# 2728  5070670090         5   7067    90     2021            39
# 2729  5073650001         5   7365     1     2021          2600
# 2730  5075840099         5   7584    99     2021           110
#
#               STREET NAME  Postcode BLDG_CLASS  TAXCLASS  ...    Borough  \
# 0            PEARL STREET     10004         H3         4  ...  MANHATTAN
# ...

# %%
hotels_df = hotels_df.drop(['STREET NUMBER', 'STREET NAME', 'BLOCK', 'LOT', 'TAXYEAR', 'BLDG_CLASS', 'TAXCLASS', 'OWNER_NAME', 'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL'], 1)
hotels_df
# Out:
#            PARID  BOROCODE  Postcode    Borough   Latitude  Longitude  \
# 0     1000080039         1     10004  MANHATTAN  40.703235 -74.012421
# 1     1000080051         1     10004  MANHATTAN  40.702744 -74.012201
# 2     1000100033         1     10004  MANHATTAN  40.704025 -74.012638
# 3     1000110029         1     10004  MANHATTAN  40.704039 -74.012317
# 4     1000161301         1     10282  MANHATTAN  40.714812 -74.016153
# ...          ...       ...       ...        ...        ...        ...
# 2726  5038750026         5     10306  STATEN IS  40.571192 -74.091057
# 2727  5066680094         5     10309  STATEN IS  40.515283 -74.194552
# 2728  5070670090         5     10309  STATEN IS  40.553824 -74.216904
# 2729  5073650001         5     10309  STATEN IS  40.533481 -74.224756
# 2730  5075840099         5     10309  STATEN IS  40.525055 -74.237788
#
#                                              NTA           Street_Address
# ...

# %%
hotels_df.to_csv('Hotels_Transformed.csv', index=False)
